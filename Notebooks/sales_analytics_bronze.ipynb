# %%
df = spark.read.csv("/Volumes/sales_analytics/bronze/raw_files/sales_data.csv",
                    header=True,
                    inferSchema=True
                    )

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("sales_analytics.bronze.sales_raw")

# %%
display(spark.sql("select * from sales_analytics.bronze.sales_raw"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
